# %%
from lanelinedetect.inference_api import *
import matplotlib.pyplot as plt

# %%
name = 'mobilenet'   # 模型使用的backbone名称, 还有一种使用xception作为backbone的模型，模型较大，不便下载
model_path = 'model_mobilenet.pth.tar'    # 模型文件路径
img_name = 'test_img.jpg'   # 待测试图片路径
model = load_model_from_path(name=name, model_path=model_path)    # 加载模型
mask_img = test(model, img_name)  # 模型推理预测
mask_img.save('test_mask.png')  #保存分割结果到图片
# 显示原图与结果图
plt.figure()
plt.imshow(Image.open(img_name))
plt.figure()
plt.imshow(mask_img)
